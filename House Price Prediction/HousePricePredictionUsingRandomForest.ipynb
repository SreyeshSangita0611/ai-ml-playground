# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ==========================================================
# LOAD DATASET
# ==========================================================
import pandas as pd
# Read CSV file from Google Drive
file_path = "/content/drive/MyDrive/Colab Notebooks/Models Data/house_prices_practice.csv"
df = pd.read_csv(file_path)

# %%
print(df.shape)
# Out:
# (299, 10)

# %%
print(df.head())
# Out:
#    Id  OverallQual  GrLivArea  GarageCars  TotalBsmtSF  YearBuilt  FullBath  \
# 0   1            7       1560           0         1658       1969         2
# 1   2            4       2827           2         1319       2012         3
# 2   3            8       3920           0          841       2010         1
# 3   4            5       3044           0         1058       1998         0
# 4   5            7        801           1         2428       2020         0
#
#    BedroomAbvGr  LotArea  SalePrice
# 0             1     8059     177106
# 1             4    13530     301044
# 2             4     9010     360609
# 3             4    13207     240556
# 4             1     9117     193656

# %%
X=df.drop(["Id","SalePrice"],axis=1)
y=df["SalePrice"]
print(X.columns)
# Out:
# Index(['OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'YearBuilt',
#        'FullBath', 'BedroomAbvGr', 'LotArea'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators =100,max_depth=None,random_state=42)
rf_model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred =rf_model.predict(X_test)
print(y_pred)
# Out:
# [201214.7  204411.42 299339.87 213470.33 359900.28 270357.72 204256.43
#  202110.55 185666.45 154474.82 184838.57 237001.5  185251.44 242167.09
#  291015.18 281660.54 265419.39 186620.91 313774.29 257722.76 340110.26
#  318716.4  318727.53 262025.   312696.1  245108.46 175042.13 224888.61
#  150482.01 184162.98 379206.5  126113.38 152586.22 205815.62 189272.79
#  335543.18 160682.93 203877.37 192006.53 310076.6  270271.14 192120.78
#  203231.76 334743.55 222339.54 181721.11 182560.42 173528.99 291239.2
#  315476.81 305486.89 191219.96 209454.83 285708.92 142970.48 168606.58
#  287980.9  163053.1  190267.89 246481.84 155163.45 248642.21 325729.7
#  363321.29 358802.59 287844.33 247219.6  140572.09 335396.44 343285.89
#  228646.12 200406.91 205216.93 190777.06 264425.16 369798.74 275887.21
#  294910.61 340472.01 245058.33 317976.93 144031.64 162036.03 364335.91
#  281369.51 210870.63 169511.72 266698.11 173671.86 298642.03]

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)

print("MAE :: ",mae)
print("MSE :: ",mse)
print("R2  :: ",r2)
# Out:
# MAE ::  23682.122777777775
# MSE ::  916704549.172779
# R2  ::  0.8507332961517573

# %%
results=pd.DataFrame({
    "Actual":y_test,
    "Predicted":y_pred
})
print(results.head(10))
# Out:
#      Actual  Predicted
# 281  225589  201214.70
# 265  181535  204411.42
# 164  290763  299339.87
# 9    211664  213470.33
# 77   353246  359900.28
# 278  265591  270357.72
# 93   215533  204256.43
# 109  209025  202110.55
# 5    213952  185666.45
# 173  153184  154474.82

# %%
sample_house =[[9,	1667,	0,	988,	1958,	2,	1,	14553]]
predicted_price=rf_model.predict(sample_house)
print("Rs",round(predicted_price[0],2))
# Out:
# Rs 209651.17
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
